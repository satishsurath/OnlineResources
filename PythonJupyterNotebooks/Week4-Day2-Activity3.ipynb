# %% [raw]
# Import the pandas and pathlib libraries.
#
# Create a variable csvpath that represents the path to the people_reordered.csv using the Pathlib library.
#
# Read the CSV into a Pandas DataFrame and display a few rows.

# %%
import pandas as pd
import pathlib as path
csvpath = "Resources/Week4-Day2-Activity3-people_reordered.csv"
df = pd.read_csv(csvpath)
df.head(10)
# Out:
#    Unnamed: 0  Person_ID    Last_Name  First_Name  Gender  \
# 0           0        1.0    Lenormand     Keriann  Female
# 1           1        2.0        Rupke     Huntley    Male
# 2           2        3.0  Dalgarnowch      Gorden    Male
# 3           3        4.0          NaN      Cullie    Male
# 4           4        5.0    Strangman       Ariel  Female
# 5           5        6.0    Snozzwell     Antonio    Male
# 6           6        7.0     Neathway       Darya  Female
# 7           7        8.0       Duding     Helaina  Female
# 8           8        9.0   Franzolini  Gerhardine  Female
# 9           9       10.0        Traut       Charo  Female
#
#                                           University  \
# 0                                  Aurora University
# 1                      Osaka University of Economics
# 2                                  Ludong University
# 3  Université des Sciences et de la Technologie d...
# 4                             Boise State University
# ...

# %% [raw]
# View the column data types.
#
# Drop the extraneous column Unnamed: 0.

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# Person_ID     float64
# Last_Name      object
# First_Name     object
# Gender         object
# University     object
# Occupation     object
# Salary        float64
# Email          object
# Age             int64
# dtype: object

# %%
#df.drop('Unnamed: 0', inplace=True)
df.drop(columns=['Unnamed: 0'], inplace=True)
df.head()
# Out:
#    Person_ID    Last_Name First_Name  Gender  \
# 0        1.0    Lenormand    Keriann  Female
# 1        2.0        Rupke    Huntley    Male
# 2        3.0  Dalgarnowch     Gorden    Male
# 3        4.0          NaN     Cullie    Male
# 4        5.0    Strangman      Ariel  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary                            Email  Age
# 0  58135.0  klenormand0@businessinsider.com   27
# 1  96053.0              hrupke1@reuters.com   22
# 2  59196.0      gdalgarnowch2@microsoft.com   40
# 3  88493.0               cputten3@nymag.com   62
# ...

# %% [raw]
# Identify data quality issues:
#
#     Identify the number of rows in the DataFrame.
#
#     Identify the frequency counts of the First_Name column. This should identify the number of times a specific name occurs.
#
#     Identify any null values in the DataFrame using the isnull function.
#
#     Determine the number of nulls in the DataFrame using the isnull function in conjunction with the sum function.
#
#     Determine the percentage of nulls for each column by chaining the isnull and sum functions then dividing by the len of the DataFrame. Multiply by 100 to produce a percentage rather than a decimal number.
#
#     Check for duplicate rows using the duplicated function.
#
#     Check for duplicate first_name and last_name values using the duplicated function.

# %%
df.shape
# Out:
# (1000, 9)

# %%
#gapminder['continent'].value_counts()
df['First_Name'].value_counts()
# Out:
# Israel       3
# Ailbert      3
# Jonell       2
# Joey         2
# Onofredo     2
#             ..
# Evaleen      1
# Ryley        1
# Tomaso       1
# Augustine    1
# Paten        1
# Name: First_Name, Length: 914, dtype: int64

# %% [markdown]
# https://miamioh.instructure.com/courses/38817/pages/data-cleaning
# ```
# bikedata.isnull()  # checking missing values
# bikedata.notnull()  # checking non-missing values
# bikedata.isnull().values.any()  # only want to know if there are any missing values
# bikedata.notnull().sum()  # knowling number of non-missing values for each variable
# bikedata.isnull().sum().sum()  # knowing how many missing values in the data
# bikedata["CNN"].isnull().values.any()  # only want to know if there are any missing values in CNN
# bikedata["TO_ST"].isnull().values.any()
# bikedata["TO_ST"].isnull().sum()  # return the number of missing values in TO_ST
# ```

# %%
df.isnull().sum()
# Out:
# Person_ID      4
# Last_Name     10
# First_Name     7
# Gender         2
# University     9
# Occupation     2
# Salary         2
# Email          8
# Age            0
# dtype: int64

# %% [markdown]
# https://miamioh.instructure.com/courses/38817/pages/data-cleaning
#
# ```
# bikedata[bikedata["TO_ST"].notnull()]  # the data contain rows that no missing values in TO_ST
# bikedata[bikedata["FROM_ST"].notnull() & bikedata["TO_ST"].notnull()]
# # the data contain rows that no missing values in FROM_ST and TO_ST
# no_missing = bikedata.dropna()  # drop missing values and assign the data to no_missing
# clean_missing_rows = bikedata.dropna(how="all")  # drop rows where all cells in the row in NA and assign the data to clean_missing_rows
# bikedata.dropna(axis=1, how="all")  # drop columns if they only contain missing values
# bikedata.dropna(thresh=25)  # drop rows that contain less than 25 non-missing values
# ```

# %%
df[df["First_Name"].isnull()]
# Out:
#      Person_ID  Last_Name First_Name  Gender  \
# 160      161.0      Emson        NaN  Female
# 308      309.0  Prozescky        NaN  Female
# 396      397.0   Schulken        NaN    Male
# 591      592.0   McCartan        NaN    Male
# 785      786.0   Kimbling        NaN  Female
# 826      827.0  Kilgallon        NaN  Female
# 921      922.0     Lorden        NaN  Female
#
#                                             University  \
# 160               Universitas Sarjanawiyata Tamansiswa
# 308                   Royal Military College of Canada
# 396         Berean University of the Assemblies of God
# 591            Kumoh National University of Technology
# 785                       Al-Batterjee Medical College
# 826  Pennsylvania State University at Harrisburg - ...
# 921                                                NaN
#
#                                Occupation    Salary  \
# 160  Business Systems Development Analyst   77143.0
# ...

# %%
df[df["Last_Name"].isnull()]
# Out:
#      Person_ID Last_Name First_Name  Gender  \
# 3          4.0       NaN     Cullie    Male
# 110      111.0       NaN      Marie  Female
# 236      237.0       NaN     Kennan    Male
# 267      268.0       NaN   Granthem    Male
# 481      482.0       NaN      Mikey    Male
# 498      499.0       NaN       Dita  Female
# 545      546.0       NaN     Kizzie  Female
# 852      853.0       NaN    Ailbert    Male
# 952      953.0       NaN     Perren    Male
# 989      990.0       NaN      Urson    Male
#
#                                             University  \
# 3    Université des Sciences et de la Technologie d...
# 110                Imperial College School of Medicine
# 236                        Northeast Normal University
# 267  Les Roches International School of Hotel Manag...
# 481              Madhya Pradesh Bhoj (Open) University
# 498                          Columbus State University
# 545                    Iceland University of Education
# ...

# %%
df[df["Person_ID"].isnull()]
# Out:
#      Person_ID  Last_Name First_Name  Gender  \
# 340        NaN  Escalante    Zebedee    Male
# 499        NaN  Billyeald  Natividad  Female
# 666        NaN   Hathwood    Hillary  Female
# 778        NaN    Kindred     Guthry    Male
#
#                                             University  \
# 340                    Tver State Technical University
# 499                             Kwara State Polytecnic
# 666  Fairleigh Dickinson University, Teaneck-Hacken...
# 778                         Fukuyama Heisei University
#
#                          Occupation   Salary                      Email  Age
# 340  Payment Adjustment Coordinator  82583.0    zescalante9g@eepurl.com   37
# 499                       Professor  52118.0       nbillyealddv@hhs.gov   48
# 666    Structural Analysis Engineer  53209.0  hhathwoodii@clickbank.net   31
# 778    Human Resources Assistant IV  64500.0    gkindredlm@geocities.jp   42

# %%
df[df["University"].isnull() | df["Person_ID"].isnull() | df["Last_Name"].isnull() | df["First_Name"].isnull()]
# Out:
#      Person_ID   Last_Name First_Name  Gender  \
# 3          4.0         NaN     Cullie    Male
# 30        31.0     Staddom     Pancho    Male
# 110      111.0         NaN      Marie  Female
# 143      144.0  Ambrogioni    Morgana  Female
# 160      161.0       Emson        NaN  Female
# 185      186.0      Dormon       Etta  Female
# 236      237.0         NaN     Kennan    Male
# 267      268.0         NaN   Granthem    Male
# 283      284.0      Dumphy    Madelle  Female
# 308      309.0   Prozescky        NaN  Female
# 340        NaN   Escalante    Zebedee    Male
# 396      397.0    Schulken        NaN    Male
# 440      441.0      Kochel     Ransom    Male
# 481      482.0         NaN      Mikey    Male
# 498      499.0         NaN       Dita  Female
# 499        NaN   Billyeald  Natividad  Female
# 545      546.0         NaN     Kizzie  Female
# 591      592.0    McCartan        NaN    Male
# 665      666.0     Rubinek   Margalit  Female
# ...

# %%
#df_missing = df[df["Person_ID"].isnull()]
#df_missing.append(df[df["University"].isnull()])
#len(df_missing)
len(df[df["University"].isnull() | df["Person_ID"].isnull() | df["Last_Name"].isnull() | df["First_Name"].isnull()])
# Out:
# 29

# %%
df[df["Person_ID"] == 952]
# Out:
#      Person_ID Last_Name First_Name  Gender  \
# 951      952.0   Bradman   Quintana  Female
#
#                                           University           Occupation  \
# 951  Dr. Babasaheb Ambedkar Technological University  Geological Engineer
#
#       Salary              Email  Age
# 951  78285.0  qbradmanqf@ft.com   37

# %%
#checing if the duplicates in the Firstname "Israel" are duplicates or valid data
df[df["First_Name"] == 'Israel']
# Out:
#      Person_ID    Last_Name First_Name Gender                      University  \
# 271      272.0    Hunnaball     Israel   Male  Jilin University of Technology
# 604      605.0  Tittershill     Israel   Male        University of Evansville
# 767      768.0      Butters     Israel   Male    Nara University of Education
#
#                     Occupation    Salary                          Email  Age
# 271       Help Desk Technician   87882.0           ihunnaball7j@psu.edu   23
# 604          Financial Analyst  119962.0  itittershillgs@yellowbook.com   40
# 767  Account Representative II   54117.0           ibutterslb@hc360.com   36

# %%
df[df["Person_ID"].isnull()]
# Out:
#      Person_ID  Last_Name First_Name  Gender  \
# 340        NaN  Escalante    Zebedee    Male
# 499        NaN  Billyeald  Natividad  Female
# 666        NaN   Hathwood    Hillary  Female
# 778        NaN    Kindred     Guthry    Male
#
#                                             University  \
# 340                    Tver State Technical University
# 499                             Kwara State Polytecnic
# 666  Fairleigh Dickinson University, Teaneck-Hacken...
# 778                         Fukuyama Heisei University
#
#                          Occupation   Salary                      Email  Age
# 340  Payment Adjustment Coordinator  82583.0    zescalante9g@eepurl.com   37
# 499                       Professor  52118.0       nbillyealddv@hhs.gov   48
# 666    Structural Analysis Engineer  53209.0  hhathwoodii@clickbank.net   31
# 778    Human Resources Assistant IV  64500.0    gkindredlm@geocities.jp   42

# %%
# For the Entries where Person_ID is missing we will add the Value "Index + 1" as their "Person_ID" 

#This is the code to list the index
df[df["Person_ID"] == 952].index[0]
# Out:
# 951

# %%
#therefore Index + 1 will be df[df["Person_ID"] == 952].index[0] +1
temp = df[df["Person_ID"] == 952].index[0] + 1
temp
# Out:
# 952

# %%
# Now that we have this - lets try this operation for the Entries where "Person_ID" is null
# code: dataframe.at[index,'column-name']='new value'
# this should be df.at[df["Person_ID"].isnull(),"Person_ID"]=df[df["Person_ID"] == 952].index[0] + 1

for a in df[df["Person_ID"].isnull()]:
    df["Person_ID"] = df.index +1 
    #print(a[0])
    #a["Person_ID"] = each.index[0] + 1

#df.at[340,'Person_ID']= 341

# %%
len(df[df["Person_ID"].isnull()])
# Out:
# 0

# %%
df.head()
# Out:
#    Person_ID    Last_Name First_Name  Gender  \
# 0          1    Lenormand    Keriann  Female
# 1          2        Rupke    Huntley    Male
# 2          3  Dalgarnowch     Gorden    Male
# 3          4          NaN     Cullie    Male
# 4          5    Strangman      Ariel  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary                            Email  Age
# 0  58135.0  klenormand0@businessinsider.com   27
# 1  96053.0              hrupke1@reuters.com   22
# 2  59196.0      gdalgarnowch2@microsoft.com   40
# 3  88493.0               cputten3@nymag.com   62
# ...
