# %%
import pandas as pd
df_customer = pd.read_csv("Resources/Week3-Day3-Activity7customer_info.csv",index_col="CustomerID")
df_fr = pd.read_csv("Resources/Week3-Day3-Activity7france_products.csv",index_col="CustomerID")
df_nl = pd.read_csv("Resources/Week3-Day3-Activity7netherlands_products.csv",index_col="CustomerID")
df_products = pd.read_csv("Resources/Week3-Day3-Activity7products.csv",index_col="CustomerID")
df_uk = pd.read_csv("Resources/Week3-Day3-Activity7uk_products.csv",index_col="CustomerID")

# %%
df_customer.head(10)
# Out:
#             FirstName       LastName                    Address          City  \
# CustomerID
# 12583       Christine        Lagarde  26  rue des Nations Unies  SAINT-BENOÎT
# 17069            John        Grayken               73  Red Lane      Evershot
# 14646           Frits  Goldschmeding              Nassaupark 84        Bussum
#
#              Postal  Country     JoinDate
# CustomerID
# 12583         97470   France  2012-09-12
# 17069       DT2 5JB       UK   2010-04-24
# 14646       1405 HP  Holland   2017-01-19

# %%
df_fr.head(10)
# Out:
#             InvoiceNo  StockCode                          Description  \
# CustomerID
# 12583          536370      10002          INFLATABLE POLITICAL GLOBE
# 12583          536370      21791   VINTAGE HEADS AND TAILS CARD GAME
# 12583          536370      21035      SET/2 RED RETROSPOT TEA TOWELS
# 12583          536370      22326  ROUND SNACK BOXES SET OF4 WOODLAND
# 12583          536370      22629                  SPACEBOY LUNCH BOX
# 12583          536370      22659              LUNCH BOX I LOVE LONDON
# 12583          536370      22544                 MINI JIGSAW SPACEBOY
#
#             Quantity     InvoiceDate  UnitPrice Country
# CustomerID
# 12583             48  12/1/2010 8:45       0.85  France
# 12583             24  12/1/2010 8:45       1.25  France
# 12583             18  12/1/2010 8:45       2.95  France
# 12583             24  12/1/2010 8:45       2.95  France
# 12583             24  12/1/2010 8:45       1.95  France
# ...

# %%
df_nl.head(10)
# Out:
#             InvoiceNo StockCode                          Description  \
# CustomerID
# 14646          539491     21981         PACK OF 12 WOODLAND TISSUES
# 14646          539491     21986     PACK OF 12 PINK POLKADOT TISSUES
# 14646          539491     21123  SET/10 IVORY POLKADOT PARTY CANDLES
# 14646          539491    47599A                      PINK PARTY BAGS
# 14646          539491     22331     WOODLAND PARTY BAG + STICKER SET
# 14646          539491     22333    RETROSPOT PARTY BAG + STICKER SET
# 14646          539491     22315         200 RED + WHITE BENDY STRAWS
# 14646          539491     22445        PENCIL CASE LIFE IS BEAUTIFUL
#
#             Quantity       InvoiceDate  UnitPrice      Country
# CustomerID
# 14646             12  12/20/2010 10:09       0.29  Netherlands
# 14646             12  12/20/2010 10:09       0.29  Netherlands
# 14646              2  12/20/2010 10:09       1.25  Netherlands
# 14646              2  12/20/2010 10:09       2.10  Netherlands
# ...

# %%
df_uk.head(10)
# Out:
#             InvoiceNo StockCode                         Description  Quantity  \
# CustomerID
# 17069          539490     22720   SET OF 3 CAKE TINS PANTRY DESIGN          6
# 17069          539490     22721       SET OF 3 CAKE TINS SKETCHBOOK         3
# 17069          539490     22722   SET OF 6 SPICE TINS PANTRY DESIGN         8
# 17069          539490     22723       SET OF 6 HERB TINS SKETCHBOOK         4
# 17069          539490     22961              JAM MAKING SET PRINTED        12
# 17069          539490     22178     VICTORIAN GLASS HANGING T-LIGHT        12
# 17069          539490    84997A  GREEN 3 PIECE POLKADOT CUTLERY SET         6
#
#                  InvoiceDate  UnitPrice         Country
# CustomerID
# 17069       12/20/2010 10:00       4.95  United Kingdom
# 17069       12/20/2010 10:00       4.95  United Kingdom
# 17069       12/20/2010 10:00       3.95  United Kingdom
# 17069       12/20/2010 10:00       3.95  United Kingdom
# ...

# %%
df_products.head(10)
# Out:
#             InvoiceNo  StockCode                        Description  Quantity  \
# CustomerID
# 14646          539491      21981       PACK OF 12 WOODLAND TISSUES         12
# 17069          539490      22665  RECIPE BOX BLUE SKETCHBOOK DESIGN        12
# 12583          540455      22726         ALARM CLOCK BAKELIKE GREEN        16
#
#                  InvoiceDate  UnitPrice         Country
# CustomerID
# 14646       12/20/2010 10:09       0.29     Netherlands
# 17069       12/20/2010 10:00       2.95  United Kingdom
# 12583         1/7/2011 12:07       3.75          France

# %%
df_summary = pd.concat([df_uk,df_nl,df_fr,df_products])
df_summary.head(10)
# Out:
#             InvoiceNo StockCode                          Description  \
# CustomerID
# 17069          539490     22720    SET OF 3 CAKE TINS PANTRY DESIGN
# 17069          539490     22721        SET OF 3 CAKE TINS SKETCHBOOK
# 17069          539490     22722    SET OF 6 SPICE TINS PANTRY DESIGN
# 17069          539490     22723        SET OF 6 HERB TINS SKETCHBOOK
# 17069          539490     22961               JAM MAKING SET PRINTED
# 17069          539490     22178      VICTORIAN GLASS HANGING T-LIGHT
# 17069          539490    84997A   GREEN 3 PIECE POLKADOT CUTLERY SET
# 14646          539491     21981         PACK OF 12 WOODLAND TISSUES
# 14646          539491     21986     PACK OF 12 PINK POLKADOT TISSUES
# 14646          539491     21123  SET/10 IVORY POLKADOT PARTY CANDLES
#
#             Quantity       InvoiceDate  UnitPrice         Country
# CustomerID
# 17069              6  12/20/2010 10:00       4.95  United Kingdom
# ...

# %%
df_summary.duplicated().mean()
# Out:
# 0.0

# %%
df_summary.drop_duplicates()
# Out:
#             InvoiceNo StockCode                          Description  \
# CustomerID
# 17069          539490     22720    SET OF 3 CAKE TINS PANTRY DESIGN
# 17069          539490     22721        SET OF 3 CAKE TINS SKETCHBOOK
# 17069          539490     22722    SET OF 6 SPICE TINS PANTRY DESIGN
# 17069          539490     22723        SET OF 6 HERB TINS SKETCHBOOK
# 17069          539490     22961               JAM MAKING SET PRINTED
# 17069          539490     22178      VICTORIAN GLASS HANGING T-LIGHT
# 17069          539490    84997A   GREEN 3 PIECE POLKADOT CUTLERY SET
# 14646          539491     21981         PACK OF 12 WOODLAND TISSUES
# 14646          539491     21986     PACK OF 12 PINK POLKADOT TISSUES
# 14646          539491     21123  SET/10 IVORY POLKADOT PARTY CANDLES
# 14646          539491    47599A                      PINK PARTY BAGS
# 14646          539491     22331     WOODLAND PARTY BAG + STICKER SET
# ...

# %%
len(df_customer)
# Out:
# 3

# %%
df_summary_with_Customer_Data = pd.merge(df_summary,df_customer,how='left',left_on = df_summary.index, right_on = df_customer.index)
df_summary_with_Customer_Data
# Out:
#     key_0  InvoiceNo StockCode                          Description  Quantity  \
# 0   17069     539490     22720    SET OF 3 CAKE TINS PANTRY DESIGN          6
# 1   17069     539490     22721        SET OF 3 CAKE TINS SKETCHBOOK         3
# 2   17069     539490     22722    SET OF 6 SPICE TINS PANTRY DESIGN         8
# 3   17069     539490     22723        SET OF 6 HERB TINS SKETCHBOOK         4
# 4   17069     539490     22961               JAM MAKING SET PRINTED        12
# 5   17069     539490     22178      VICTORIAN GLASS HANGING T-LIGHT        12
# 6   17069     539490    84997A   GREEN 3 PIECE POLKADOT CUTLERY SET         6
# 7   14646     539491     21981         PACK OF 12 WOODLAND TISSUES         12
# 8   14646     539491     21986     PACK OF 12 PINK POLKADOT TISSUES        12
# 9   14646     539491     21123  SET/10 IVORY POLKADOT PARTY CANDLES         2
# 10  14646     539491    47599A                      PINK PARTY BAGS         2
# ...
