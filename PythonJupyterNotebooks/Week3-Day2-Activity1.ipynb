# %% [markdown]
# # Week 3 - Day 2 - Acivity 1: 01-Ins_Reading_CSVs
#
# ### https://utoronto.bootcampcontent.com/utoronto-bootcamp/UTOR-VIRT-FIN-PT-02-2022-U-LOL/-/tre[…]ies/W03-Python-Pandas/2/Activities/01-Ins_Reading_CSVs

# %%
import pandas as pd
df1 = pd.read_csv("Resources/Week3-Day2-sales.csv")

# %%
# This uses the header=None parameter in read_csv for Pandas - where we skip the Headers
df2 = pd.read_csv("Resources/Week3-Day2-sales_no_header.csv",header=None)

# %%
# Get the first 10 rows
df1.head(10)
# Out:
#           FullName                      Email                   Address  \
# 0    Elwanda White         alyre2036@live.com        352 Lakeshore Mall
# 1   Lyndon Elliott     arrowy1873@outlook.com          1234 Avery Plaza
# 2   Daisey Sellers     toucan2024@outlook.com         469 Elwood Street
# 3     Issac Reeves       asarin1958@gmail.com          565 Phelps Field
# 4  Bradford Kinney     mibound1801@yandex.com  853 Mission Rock Freeway
# 5     Fermina Cobb    kingfisher2013@live.com          929 Prague Trail
# 6  Merrill Andrews        beechy2059@live.com          41 Clarion Drive
# 7   Claris Pearson     kiwifruit2045@live.com          638 Lundeen Park
# 8  Georgiann Black  tattooage1863@outlook.com    1139 San Lorenzo Green
# 9     Carlos Hicks    lengthen1993@yandex.com       1218 Angelos Parade
#
#      Zip           CreditCard  SalePrice
# 0   9236  5327 0855 9720 7055      84.33
# 1   1330    3717 498777 19636     879.95
# 2   7631    3758 579477 35734     907.58
# ...

# %%
#shows the number of Rows and Columns
df1.shape
# Out:
# (100, 6)

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.describe()
# Out:
#                 Zip   SalePrice
# count    100.000000  100.000000
# mean   40952.160000  533.007200
# std    30207.118496  275.531072
# min      555.000000   29.720000
# 25%    11109.750000  328.507500
# 50%    40033.500000  536.110000
# 75%    65834.750000  767.885000
# max    99877.000000  998.760000

# %%
df1.columns
# Out:
# Index(['FullName', 'Email', 'Address', 'Zip', 'CreditCard', 'SalePrice'], dtype='object')

# %%
df1['SalePrice']
# Out:
# 0      84.33
# 1     879.95
# 2     907.58
# 3     545.88
# 4     517.49
#        ...
# 95    937.14
# 96    645.82
# 97    128.73
# 98    820.00
# 99    764.69
# Name: SalePrice, Length: 100, dtype: float64

# %%
type(df1['SalePrice'])
#this is no longer a DataFrame - it is a Series
# Out:
# pandas.core.series.Series

# %%
df1[['SalePrice']]
# Out:
#     SalePrice
# 0       84.33
# 1      879.95
# 2      907.58
# 3      545.88
# 4      517.49
# ..        ...
# 95     937.14
# 96     645.82
# 97     128.73
# 98     820.00
# 99     764.69
#
# [100 rows x 1 columns]

# %%
type(df1[['SalePrice']])
# use Double Square Brackets for retaining the type as Data Frame
# Out:
# pandas.core.frame.DataFrame

# %%
# We are now able to create a new column
df1[['SalePriceWithTax']] = df1[['SalePrice']]*1.13

# %%
df1.head()
# Out:
#           FullName                   Email                   Address    Zip  \
# 0    Elwanda White      alyre2036@live.com        352 Lakeshore Mall   9236
# 1   Lyndon Elliott  arrowy1873@outlook.com          1234 Avery Plaza   1330
# 2   Daisey Sellers  toucan2024@outlook.com         469 Elwood Street   7631
# 3     Issac Reeves    asarin1958@gmail.com          565 Phelps Field  81168
# 4  Bradford Kinney  mibound1801@yandex.com  853 Mission Rock Freeway  41721
#
#             CreditCard  SalePrice  SalePriceWithTax
# 0  5327 0855 9720 7055      84.33           95.2929
# 1    3717 498777 19636     879.95          994.3435
# 2    3758 579477 35734     907.58         1025.5654
# 3  4400 0380 4162 1622     545.88          616.8444
# 4    3712 263405 60178     517.49          584.7637

# %%
#See all the column types
df1.dtypes
# Out:
# FullName             object
# Email                object
# Address              object
# Zip                   int64
# CreditCard           object
# SalePrice           float64
# SalePriceWithTax    float64
# dtype: object

# %%
#df1['CreditCardNumerical'] = df1['CreditCard'].str.replace(" ","")
df1['CreditCardNumerical'] = df1['CreditCard'].str.replace(" ","").astype(int)

# %%
df1.dtypes
# Out:
# FullName                object
# Email                   object
# Address                 object
# Zip                      int64
# CreditCard              object
# SalePrice              float64
# SalePriceWithTax       float64
# CreditCardNumerical      int64
# dtype: object

# %%
df1.drop(columns=['CreditCardNumerical'])
#note that the inplace attribute is false by default
# Out:
#              FullName                      Email                   Address  \
# 0       Elwanda White         alyre2036@live.com        352 Lakeshore Mall
# 1      Lyndon Elliott     arrowy1873@outlook.com          1234 Avery Plaza
# 2      Daisey Sellers     toucan2024@outlook.com         469 Elwood Street
# 3        Issac Reeves       asarin1958@gmail.com          565 Phelps Field
# 4     Bradford Kinney     mibound1801@yandex.com  853 Mission Rock Freeway
# ..                ...                        ...                       ...
# 95         Basil Rios       holloo1814@yahoo.com         605 Sloat Terrace
# 96      Hipolito Rios  calefacient2049@gmail.com   1248 Fountain Boulevard
# 97  Clayton Robertson         coner2015@live.com         230 Paper Parkway
# 98      Tony Chandler     sexillion2061@live.com      118 Flood Plantation
# 99        Cuc Mcgowan   dispatched1820@gmail.com        87 Louisiana Grove
#
#       Zip           CreditCard  SalePrice  SalePriceWithTax
# ...

# %%
df1.drop(columns=['CreditCardNumerical'], inplace=True)

# %%
df1.head()
# Out:
#           FullName                   Email                   Address    Zip  \
# 0    Elwanda White      alyre2036@live.com        352 Lakeshore Mall   9236
# 1   Lyndon Elliott  arrowy1873@outlook.com          1234 Avery Plaza   1330
# 2   Daisey Sellers  toucan2024@outlook.com         469 Elwood Street   7631
# 3     Issac Reeves    asarin1958@gmail.com          565 Phelps Field  81168
# 4  Bradford Kinney  mibound1801@yandex.com  853 Mission Rock Freeway  41721
#
#             CreditCard  SalePrice  SalePriceWithTax
# 0  5327 0855 9720 7055      84.33           95.2929
# 1    3717 498777 19636     879.95          994.3435
# 2    3758 579477 35734     907.58         1025.5654
# 3  4400 0380 4162 1622     545.88          616.8444
# 4    3712 263405 60178     517.49          584.7637

# %%
df1.columns
# Out:
# Index(['FullName', 'Email', 'Address', 'Zip', 'CreditCard', 'SalePrice',
#        'SalePriceWithTax'],
#       dtype='object')

# %%
#Notice the reordering in the next code block
df1[['FullName', 'Email', 'Address', 'Zip', 'CreditCard', 'SalePrice',
       'SalePriceWithTax']]
# Out:
#              FullName                      Email                   Address  \
# 0       Elwanda White         alyre2036@live.com        352 Lakeshore Mall
# 1      Lyndon Elliott     arrowy1873@outlook.com          1234 Avery Plaza
# 2      Daisey Sellers     toucan2024@outlook.com         469 Elwood Street
# 3        Issac Reeves       asarin1958@gmail.com          565 Phelps Field
# 4     Bradford Kinney     mibound1801@yandex.com  853 Mission Rock Freeway
# ..                ...                        ...                       ...
# 95         Basil Rios       holloo1814@yahoo.com         605 Sloat Terrace
# 96      Hipolito Rios  calefacient2049@gmail.com   1248 Fountain Boulevard
# 97  Clayton Robertson         coner2015@live.com         230 Paper Parkway
# 98      Tony Chandler     sexillion2061@live.com      118 Flood Plantation
# 99        Cuc Mcgowan   dispatched1820@gmail.com        87 Louisiana Grove
#
#       Zip           CreditCard  SalePrice  SalePriceWithTax
# ...

# %%
#Notice the reordering
df1[['Email','FullName', 'Address', 'Zip', 'CreditCard', 'SalePrice',
       'SalePriceWithTax']]
# Out:
#                         Email           FullName                   Address  \
# 0          alyre2036@live.com      Elwanda White        352 Lakeshore Mall
# 1      arrowy1873@outlook.com     Lyndon Elliott          1234 Avery Plaza
# 2      toucan2024@outlook.com     Daisey Sellers         469 Elwood Street
# 3        asarin1958@gmail.com       Issac Reeves          565 Phelps Field
# 4      mibound1801@yandex.com    Bradford Kinney  853 Mission Rock Freeway
# ..                        ...                ...                       ...
# 95       holloo1814@yahoo.com         Basil Rios         605 Sloat Terrace
# 96  calefacient2049@gmail.com      Hipolito Rios   1248 Fountain Boulevard
# 97         coner2015@live.com  Clayton Robertson         230 Paper Parkway
# 98     sexillion2061@live.com      Tony Chandler      118 Flood Plantation
# 99   dispatched1820@gmail.com        Cuc Mcgowan        87 Louisiana Grove
#
#       Zip           CreditCard  SalePrice  SalePriceWithTax
# ...

# %%
#df = df.rename(columns={'oldName1': 'newName1', 'oldName2': 'newName2'})

# %%
df1.rename(columns={'FullName': 'Full_Name'},inplace=True)
df1.head()
# Out:
#          Full_Name                   Email                   Address    Zip  \
# 0    Elwanda White      alyre2036@live.com        352 Lakeshore Mall   9236
# 1   Lyndon Elliott  arrowy1873@outlook.com          1234 Avery Plaza   1330
# 2   Daisey Sellers  toucan2024@outlook.com         469 Elwood Street   7631
# 3     Issac Reeves    asarin1958@gmail.com          565 Phelps Field  81168
# 4  Bradford Kinney  mibound1801@yandex.com  853 Mission Rock Freeway  41721
#
#             CreditCard  SalePrice  SalePriceWithTax
# 0  5327 0855 9720 7055      84.33           95.2929
# 1    3717 498777 19636     879.95          994.3435
# 2    3758 579477 35734     907.58         1025.5654
# 3  4400 0380 4162 1622     545.88          616.8444
# 4    3712 263405 60178     517.49          584.7637

# %%
df1['Zip'].value_counts()
# Out:
# 9236     1
# 37881    1
# 1771     1
# 81524    1
# 24627    1
#         ..
# 49688    1
# 27711    1
# 75745    1
# 61738    1
# 70959    1
# Name: Zip, Length: 100, dtype: int64

# %%
df1['Zip'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: Zip, Length: 100, dtype: bool

# %%
df1['Zip'].isnull().mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: Zip, Length: 100, dtype: bool>
