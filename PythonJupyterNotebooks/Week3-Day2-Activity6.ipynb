# %%
import pandas as pd
df = pd.read_csv("Resources/Week3-Day2-Activity6-people.csv")

# %%
df.shape
df.head()
# Out:
#   first_name   last_name gender  age             company_name  \
# 0    Aleshia  Tomkiewicz      F   54  Alan D Rosenburg Cpa Pc
# 1       Evan   Zigomalas      M   47       Cap Gemini America
# 2     France     Andrade      M   42      Elliott, John W Esq
# 3    Ulysses   Mcwalters      M   45           Mcmahan, Ben L
# 4     Tyisha      Veness      F   37           Champagne Room
#
#              address                            city           county  \
# 0       14 Taylor St               St. Stephens Ward             Kent
# 1        5 Binney St                      Abbey Ward  Buckinghamshire
# 2       8 Moor Place  East Southbourne and Tuckton W      Bournemouth
# 3      505 Exeter Rd              Hawerby cum Beesby     Lincolnshire
# 4  5396 Forth Street      Greets Green and Lyng Ward    West Midlands
#
#      postal        phone1        phone2                       email  \
# 0   CT2 7PP  01835-703597  01944-369967     atomkiewicz@hotmail.com
# ...

# %%
# iloc is index location
# loc is location if index is not a numner
df.iloc[0]
# Out:
# first_name                                   Aleshia
# last_name                                 Tomkiewicz
# gender                                             F
# age                                               54
# company_name                 Alan D Rosenburg Cpa Pc
# address                                 14 Taylor St
# city                               St. Stephens Ward
# county                                          Kent
# postal                                       CT2 7PP
# phone1                                  01835-703597
# phone2                                  01944-369967
# email                        atomkiewicz@hotmail.com
# web             http://www.alandrosenburgcpapc.co.uk
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# first_name                                   Evan
# last_name                               Zigomalas
# gender                                          M
# age                                            47
# company_name                   Cap Gemini America
# address                               5 Binney St
# city                                   Abbey Ward
# county                            Buckinghamshire
# postal                                   HP11 2AX
# phone1                               01937-864715
# phone2                               01714-737668
# email                    evan.zigomalas@gmail.com
# web             http://www.capgeminiamerica.co.uk
# Name: 1, dtype: object

# %%
#this will get you the first 10 elements
df.iloc[0:10]
# Out:
#   first_name   last_name gender  age                   company_name  \
# 0    Aleshia  Tomkiewicz      F   54        Alan D Rosenburg Cpa Pc
# 1       Evan   Zigomalas      M   47             Cap Gemini America
# 2     France     Andrade      M   42            Elliott, John W Esq
# 3    Ulysses   Mcwalters      M   45                 Mcmahan, Ben L
# 4     Tyisha      Veness      F   37                 Champagne Room
# 5       Eric       Rampy      M   28        Thompson, Michael C Esq
# 6       Marg    Grasmick      F   44  Wrangle Hill Auto Auct & Slvg
# 7    Laquita       Hisaw      F   40          In Communications Inc
# 8       Lura    Manzella      F   53                Bizerba Usa Inc
# 9     Yuette      Klapec      F   55                      Max Video
#
#                 address                            city  \
# 0          14 Taylor St               St. Stephens Ward
# 1           5 Binney St                      Abbey Ward
# ...

# %%
df.iloc[len(df)-1] # is the same as df.iloc[-1]
# Out:
# first_name                                               Mi
# last_name                                            Richan
# gender                                                    M
# age                                                      27
# company_name                 Nelson Wright Haworth Golf Crs
# address                                     6 Norwood Grove
# city                                      Tanworth-in-Arden
# county                                         Warwickshire
# postal                                              B94 5RZ
# phone1                                         01451-785624
# phone2                                         01202-738406
# email                                        mi@hotmail.com
# web             http://www.nelsonwrighthaworthgolfcrs.co.uk
# Name: 499, dtype: object

# %%
df.iloc[-1]
# Out:
# first_name                                               Mi
# last_name                                            Richan
# gender                                                    M
# age                                                      27
# company_name                 Nelson Wright Haworth Golf Crs
# address                                     6 Norwood Grove
# city                                      Tanworth-in-Arden
# county                                         Warwickshire
# postal                                              B94 5RZ
# phone1                                         01451-785624
# phone2                                         01202-738406
# email                                        mi@hotmail.com
# web             http://www.nelsonwrighthaworthgolfcrs.co.uk
# Name: 499, dtype: object

# %%
print(df.iloc[-1] )
# Out:
# first_name                                               Mi
# last_name                                            Richan
# gender                                                    M
# age                                                      27
# company_name                 Nelson Wright Haworth Golf Crs
# address                                     6 Norwood Grove
# city                                      Tanworth-in-Arden
# county                                         Warwickshire
# postal                                              B94 5RZ
# phone1                                         01451-785624
# phone2                                         01202-738406
# email                                        mi@hotmail.com
# web             http://www.nelsonwrighthaworthgolfcrs.co.uk
# Name: 499, dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=500, step=1)

# %%
# dictionary with list object in values
details = {
    'Name' : ['Ankit', 'Aishwarya', 'Shaurya', 'Shivangi'],
    'Age' : [23, 21, 22, 21],
    'University' : ['BHU', 'JNU', 'DU', 'BHU'],
}
  
# creating a Dataframe object 
df_example = pd.DataFrame(details)

# %%
df_example
# Out:
#         Name  Age University
# 0      Ankit   23        BHU
# 1  Aishwarya   21        JNU
# 2    Shaurya   22         DU
# 3   Shivangi   21        BHU

# %%
# here ,1 shows the column
df.iloc[:,1]
# Out:
# 0      Tomkiewicz
# 1       Zigomalas
# 2         Andrade
# 3       Mcwalters
# 4          Veness
#           ...
# 495          Veit
# 496       Euresti
# 497      Brenning
# 498         Keeny
# 499        Richan
# Name: last_name, Length: 500, dtype: object

# %%
# here ,1 to 5shows the column
df.iloc[:,1:5]
# Out:
#       last_name gender  age                    company_name
# 0    Tomkiewicz      F   54         Alan D Rosenburg Cpa Pc
# 1     Zigomalas      M   47              Cap Gemini America
# 2       Andrade      M   42             Elliott, John W Esq
# 3     Mcwalters      M   45                  Mcmahan, Ben L
# 4        Veness      F   37                  Champagne Room
# ..          ...    ...  ...                             ...
# 495        Veit      M   38      Plaza Gourmet Delicatessen
# 496     Euresti      M   56            Fitzgerald, Edward J
# 497    Brenning      F   31              Furey & Associates
# 498       Keeny      F   41        Bfg Federal Credit Union
# 499      Richan      M   27  Nelson Wright Haworth Golf Crs
#
# [500 rows x 4 columns]

# %%
#this will take roses 5 to 10 and columns 1 to 5
df.iloc[5:10,1:5]
# Out:
#   last_name gender  age                   company_name
# 5     Rampy      M   28        Thompson, Michael C Esq
# 6  Grasmick      F   44  Wrangle Hill Auto Auct & Slvg
# 7     Hisaw      F   40          In Communications Inc
# 8  Manzella      F   53                Bizerba Usa Inc
# 9    Klapec      F   55                      Max Video

# %%
df[df['age']>50]
# Out:
#     first_name   last_name gender  age                  company_name  \
# 0      Aleshia  Tomkiewicz      F   54       Alan D Rosenburg Cpa Pc
# 8         Lura    Manzella      F   53               Bizerba Usa Inc
# 9       Yuette      Klapec      F   55                     Max Video
# 15     Michell   Throssell      M   54           Weiss Spirt & Guyer
# 20       Peter   Gutierres      M   55    Niagara Custombuilt Mfg Co
# ..         ...         ...    ...  ...                           ...
# 487   Isabelle        Kono      F   58  Rock Springs Petroleum Equip
# 488     Ronnie     Brigman      M   57                Howard Johnson
# 492     Elbert     Fiorino      M   53          Donald, G Nelson Esq
# 493       Pura     Manciel      F   54                Cia Inspection
# 496       Reid     Euresti      M   56          Fitzgerald, Edward J
#
#                     address                      city                 county  \
# ...

# %%
df[(df['age']>50) & (df['first_name']=="Aleshia")]
# Out:
#   first_name   last_name gender  age             company_name       address  \
# 0    Aleshia  Tomkiewicz      F   54  Alan D Rosenburg Cpa Pc  14 Taylor St
#
#                 city county   postal        phone1        phone2  \
# 0  St. Stephens Ward   Kent  CT2 7PP  01835-703597  01944-369967
#
#                      email                                   web
# 0  atomkiewicz@hotmail.com  http://www.alandrosenburgcpapc.co.uk

# %%
df['fullname'] = df['first_name'] + " " + df['last_name']

# %%
df
# Out:
#     first_name   last_name gender  age                    company_name  \
# 0      Aleshia  Tomkiewicz      F   54         Alan D Rosenburg Cpa Pc
# 1         Evan   Zigomalas      M   47              Cap Gemini America
# 2       France     Andrade      M   42             Elliott, John W Esq
# 3      Ulysses   Mcwalters      M   45                  Mcmahan, Ben L
# 4       Tyisha      Veness      F   37                  Champagne Room
# ..         ...         ...    ...  ...                             ...
# 495      Avery        Veit      M   38      Plaza Gourmet Delicatessen
# 496       Reid     Euresti      M   56            Fitzgerald, Edward J
# 497  Charlette    Brenning      F   31              Furey & Associates
# 498  Celestina       Keeny      F   41        Bfg Federal Credit Union
# 499         Mi      Richan      M   27  Nelson Wright Haworth Golf Crs
#
#                 address                            city           county  \
# ...

# %%
df.set_index('fullname',inplace=False)
# Out:
#                    first_name   last_name gender  age  \
# fullname
# Aleshia Tomkiewicz    Aleshia  Tomkiewicz      F   54
# Evan Zigomalas           Evan   Zigomalas      M   47
# France Andrade         France     Andrade      M   42
# Ulysses Mcwalters     Ulysses   Mcwalters      M   45
# Tyisha Veness          Tyisha      Veness      F   37
# ...                       ...         ...    ...  ...
# Avery Veit              Avery        Veit      M   38
# Reid Euresti             Reid     Euresti      M   56
# Charlette Brenning  Charlette    Brenning      F   31
# Celestina Keeny     Celestina       Keeny      F   41
# Mi Richan                  Mi      Richan      M   27
#
#                                       company_name             address  \
# fullname
# Aleshia Tomkiewicz         Alan D Rosenburg Cpa Pc        14 Taylor St
# Evan Zigomalas                  Cap Gemini America         5 Binney St
# France Andrade                 Elliott, John W Esq        8 Moor Place
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=500, step=1)

# %%
df.set_index('fullname',inplace=True)

# %%
df.index
# Out:
# Index(['Aleshia Tomkiewicz', 'Evan Zigomalas', 'France Andrade',
#        'Ulysses Mcwalters', 'Tyisha Veness', 'Eric Rampy', 'Marg Grasmick',
#        'Laquita Hisaw', 'Lura Manzella', 'Yuette Klapec',
#        ...
#        'Rosita Ausdemore', 'Huey Stancil', 'Elbert Fiorino', 'Pura Manciel',
#        'Alesia Katie', 'Avery Veit', 'Reid Euresti', 'Charlette Brenning',
#        'Celestina Keeny', 'Mi Richan'],
#       dtype='object', name='fullname', length=500)

# %%
df = df.reset_index(level=0, drop=True).reset_index()

# %%
df.index
# Out:
# RangeIndex(start=0, stop=500, step=1)

# %%
df
# Out:
#      index first_name   last_name gender  age                    company_name  \
# 0        0    Aleshia  Tomkiewicz      F   54         Alan D Rosenburg Cpa Pc
# 1        1       Evan   Zigomalas      M   47              Cap Gemini America
# 2        2     France     Andrade      M   42             Elliott, John W Esq
# 3        3    Ulysses   Mcwalters      M   45                  Mcmahan, Ben L
# 4        4     Tyisha      Veness      F   37                  Champagne Room
# ..     ...        ...         ...    ...  ...                             ...
# 495    495      Avery        Veit      M   38      Plaza Gourmet Delicatessen
# 496    496       Reid     Euresti      M   56            Fitzgerald, Edward J
# 497    497  Charlette    Brenning      F   31              Furey & Associates
# 498    498  Celestina       Keeny      F   41        Bfg Federal Credit Union
# 499    499         Mi      Richan      M   27  Nelson Wright Haworth Golf Crs
#
# ...

# %%
df.drop(columns='index', inplace=True)

# %%
df
# Out:
#     first_name   last_name gender  age                    company_name  \
# 0      Aleshia  Tomkiewicz      F   54         Alan D Rosenburg Cpa Pc
# 1         Evan   Zigomalas      M   47              Cap Gemini America
# 2       France     Andrade      M   42             Elliott, John W Esq
# 3      Ulysses   Mcwalters      M   45                  Mcmahan, Ben L
# 4       Tyisha      Veness      F   37                  Champagne Room
# ..         ...         ...    ...  ...                             ...
# 495      Avery        Veit      M   38      Plaza Gourmet Delicatessen
# 496       Reid     Euresti      M   56            Fitzgerald, Edward J
# 497  Charlette    Brenning      F   31              Furey & Associates
# 498  Celestina       Keeny      F   41        Bfg Federal Credit Union
# 499         Mi      Richan      M   27  Nelson Wright Haworth Golf Crs
#
#                 address                            city           county  \
# ...

# %%
df.set_index('first_name',inplace=True)
df
# Out:
#              last_name gender  age                    company_name  \
# first_name
# Aleshia     Tomkiewicz      F   54         Alan D Rosenburg Cpa Pc
# Evan         Zigomalas      M   47              Cap Gemini America
# France         Andrade      M   42             Elliott, John W Esq
# Ulysses      Mcwalters      M   45                  Mcmahan, Ben L
# Tyisha          Veness      F   37                  Champagne Room
# ...                ...    ...  ...                             ...
# Avery             Veit      M   38      Plaza Gourmet Delicatessen
# Reid           Euresti      M   56            Fitzgerald, Edward J
# Charlette     Brenning      F   31              Furey & Associates
# Celestina        Keeny      F   41        Bfg Federal Credit Union
# Mi              Richan      M   27  Nelson Wright Haworth Golf Crs
#
#                        address                            city  \
# first_name
# Aleshia           14 Taylor St               St. Stephens Ward
# ...

# %%
df.loc['Aleshia']
# Out:
# last_name                                 Tomkiewicz
# gender                                             F
# age                                               54
# company_name                 Alan D Rosenburg Cpa Pc
# address                                 14 Taylor St
# city                               St. Stephens Ward
# county                                          Kent
# postal                                       CT2 7PP
# phone1                                  01835-703597
# phone2                                  01944-369967
# email                        atomkiewicz@hotmail.com
# web             http://www.alandrosenburgcpapc.co.uk
# Name: Aleshia, dtype: object

# %%
#how to change the county for Aleshia
df.loc['Aleshia','county']
# Out:
# 'Kent'

# %%
df.loc['Aleshia','county'] = "Toronto"
df.loc['Aleshia','county']
# Out:
# 'Toronto'

# %%
df
# Out:
#              last_name gender  age                    company_name  \
# first_name
# Aleshia     Tomkiewicz      F   54         Alan D Rosenburg Cpa Pc
# Evan         Zigomalas      M   47              Cap Gemini America
# France         Andrade      M   42             Elliott, John W Esq
# Ulysses      Mcwalters      M   45                  Mcmahan, Ben L
# Tyisha          Veness      F   37                  Champagne Room
# ...                ...    ...  ...                             ...
# Avery             Veit      M   38      Plaza Gourmet Delicatessen
# Reid           Euresti      M   56            Fitzgerald, Edward J
# Charlette     Brenning      F   31              Furey & Associates
# Celestina        Keeny      F   41        Bfg Federal Credit Union
# Mi              Richan      M   27  Nelson Wright Haworth Golf Crs
#
#                        address                            city  \
# first_name
# Aleshia           14 Taylor St               St. Stephens Ward
# ...
